# %% [markdown]
# # UK_FP

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
UK_data = data[data['Country'] == 'United Kingdom']

# 移除含有NaN值的行（特別是在'Description'列中）
UK_data = UK_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
UK_data['Description'] = UK_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
UK_grouped_data = UK_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
UK_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536365  WHITE HANGING HEART T-LIGHT HOLDER, WHITE META...
# 1    536366  HAND WARMER UNION JACK, HAND WARMER RED POLKA DOT
# 2    536367  ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHOU...
# 3    536368  JAM MAKING SET WITH JARS, RED COAT RACK PARIS ...
# 4    536369                           BATH BUILDING BLOCK WORD

# %%
# Splitting the Description column into individual items
UK_grouped_data['Items'] = UK_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = UK_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = fpgrowth(df, min_support=0.01, use_colnames=True)

# Generating the association rules
UK_FP_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
fp_growth_time = time.time() - start_time
print(f"Time taken for FP-growth: {fp_growth_time} seconds")
# Out:
# Time taken for FP-growth: 2.279085159301758 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
UK_FP_rules = UK_FP_rules[['antecedents', 'consequents', 'confidence', 'lift']]
UK_FP_rules
# Out:
#                                            antecedents  \
# 0                         ( POPPY'S PLAYHOUSE KITCHEN)
# 1                        ( POPPY'S PLAYHOUSE BEDROOM )
# 2                  ( RED HANGING HEART T-LIGHT HOLDER)
# 3                            ( JUMBO STORAGE BAG SUKI)
# 4    ( JUMBO SHOPPER VINTAGE RED PAISLEY,  JUMBO ST...
# ..                                                 ...
# 237                        ( REGENCY TEA PLATE ROSES )
# 238                          ( REGENCY TEA PLATE PINK)
# 239              ( GARDENERS KNEELING PAD CUP OF TEA )
# 240                    ( JUMBO BAG VINTAGE CHRISTMAS )
# 241                ( SET OF 12 MINI LOAF BAKING CASES)
#
#                                consequents  confidence       lift
# 0            ( POPPY'S PLAYHOUSE BEDROOM )    0.694595  42.762192
# 1             ( POPPY'S PLAYHOUSE KITCHEN)    0.717877  42.762192
# 2    ( WHITE HANGING HEART T-LIGHT HOLDER)    0.623123   6.836055
# 3               ( JUMBO BAG RED RETROSPOT)    0.609756   7.140821
# 4               ( JUMBO BAG RED RETROSPOT)    0.741344   8.681842
# ..                                     ...         ...        ...
# 237              ( REGENCY TEA PLATE PINK)    0.605479  50.740559
# 238            ( REGENCY TEA PLATE ROSES )    0.840304  50.740559
# 239   ( GARDENERS KNEELING PAD KEEP CALM )    0.698910  17.870044
# 240           ( JUMBO BAG 50'S CHRISTMAS )    0.664384  23.206044
# 241   ( SET OF 12 FAIRY CAKE BAKING CASES)    0.651715  31.848779
#
# [242 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = UK_FP_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                         antecedents      consequents  confidence       lift
# 103     ( FANCY FONT BIRTHDAY CARD)              ( )         1.0  41.042831
# 54                ( AIRLINE LOUNGE)     (METAL SIGN)         1.0  76.000000
# 173  (COFFEE,  SET 3 RETROSPOT TEA)          (SUGAR)         1.0  57.696335
# 169          ( SET 3 RETROSPOT TEA)          (SUGAR)         1.0  57.696335
# 177          ( SET 3 RETROSPOT TEA)  (COFFEE, SUGAR)         1.0  57.696335

# %% [markdown]
# # UK_Apriori

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)

UK_data = data[data['Country'] == 'United Kingdom']

# 移除含有NaN值的行（特別是在'Description'列中）
UK_data = UK_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
UK_data['Description'] = UK_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
UK_grouped_data = UK_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
UK_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536365  WHITE HANGING HEART T-LIGHT HOLDER, WHITE META...
# 1    536366  HAND WARMER UNION JACK, HAND WARMER RED POLKA DOT
# 2    536367  ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHOU...
# 3    536368  JAM MAKING SET WITH JARS, RED COAT RACK PARIS ...
# 4    536369                           BATH BUILDING BLOCK WORD

# %%
# Splitting the Description column into individual items
UK_grouped_data['Items'] = UK_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = UK_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Generating the association rules
UK_apriori_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
apriori_time = time.time() - start_time
print(f"Time taken for apriori: {apriori_time} seconds")
# Out:
# Time taken for apriori: 39.11946702003479 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
UK_apriori_rules = UK_apriori_rules[['antecedents', 'consequents', 'confidence', 'lift']]
UK_apriori_rules
# Out:
#                                            antecedents  \
# 0                                     ( BIRTHDAY CARD)
# 1                          ( FANCY FONT BIRTHDAY CARD)
# 2                                    ( AIRLINE LOUNGE)
# 3                                         (METAL SIGN)
# 4                    ( ALARM CLOCK BAKELIKE CHOCOLATE)
# ..                                                 ...
# 237  ( WOODLAND CHARLOTTE BAG,  STRAWBERRY CHARLOTT...
# 238  ( JUMBO SHOPPER VINTAGE RED PAISLEY,  JUMBO ST...
# 239  ( JUMBO BAG PINK POLKADOT,  JUMBO SHOPPER VINT...
# 240  ( JUMBO BAG PINK POLKADOT,  JUMBO STORAGE BAG ...
# 241  ( JUMBO SHOPPER VINTAGE RED PAISLEY,  JUMBO ST...
#
#                                            consequents  confidence       lift
# 0                                                  ( )    0.648000  26.595754
# 1                                                  ( )    1.000000  41.042831
# 2                                         (METAL SIGN)    1.000000  76.000000
# 3                                    ( AIRLINE LOUNGE)    0.986207  76.000000
# 4                        ( ALARM CLOCK BAKELIKE GREEN)    0.625337  16.119796
# ..                                                 ...         ...        ...
# 237  ( CHARLOTTE BAG SUKI DESIGN,  RED RETROSPOT CH...    0.638122  30.574345
# 238                         ( JUMBO BAG PINK POLKADOT)    0.673077  13.186325
# 239                          ( JUMBO STORAGE BAG SUKI)    0.700000  13.936766
# 240               ( JUMBO SHOPPER VINTAGE RED PAISLEY)    0.638021  12.679873
# 241                         ( JUMBO BAG RED RETROSPOT)    0.868794  10.174403
#
# [242 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = UK_apriori_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                         antecedents   consequents  confidence       lift
# 214  (COFFEE,  SET 3 RETROSPOT TEA)       (SUGAR)         1.0  57.696335
# 2                 ( AIRLINE LOUNGE)  (METAL SIGN)         1.0  76.000000
# 72                          (SUGAR)      (COFFEE)         1.0  46.893617
# 216   ( SET 3 RETROSPOT TEA, SUGAR)      (COFFEE)         1.0  46.893617
# 1       ( FANCY FONT BIRTHDAY CARD)           ( )         1.0  41.042831

# %% [markdown]
# # Germany_FP

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
Germany_data = data[data['Country'] == 'Germany']

# 移除含有NaN值的行（特別是在'Description'列中）
Germany_data = Germany_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
Germany_data['Description'] = Germany_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
Germany_grouped_data = Germany_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
Germany_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536527  SET OF 6 T-LIGHTS SANTA, ROTATING SILVER ANGEL...
# 1    536840  JAM MAKING SET PRINTED, JAM JAR WITH PINK LID,...
# 2    536861  FELTCRAFT 6 FLOWER FRIENDS, 6 RIBBONS RUSTIC C...
# 3    536967                   POSTAGE, JUMBO BAG RED RETROSPOT
# 4    536983  WOODLAND PARTY BAG + STICKER SET, HAND WARMER ...

# %%
# Splitting the Description column into individual items
Germany_grouped_data['Items'] = Germany_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = Germany_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = fpgrowth(df, min_support=0.01, use_colnames=True)

# Generating the association rules
Germany_FP_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
fp_growth_time = time.time() - start_time
print(f"Time taken for FP-growth: {fp_growth_time} seconds")
# Out:
# Time taken for FP-growth: 0.07642793655395508 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
Germany_FP_rules = Germany_FP_rules[['antecedents', 'consequents', 'confidence', 'lift']]
Germany_FP_rules
# Out:
#                                             antecedents consequents  \
# 0                         ( JUMBO BAG WOODLAND ANIMALS)  ( POSTAGE)
# 1     ( ROUND SNACK BOXES SET OF4 WOODLAND ,  JUMBO ...  ( POSTAGE)
# 2     ( JUMBO BAG WOODLAND ANIMALS,  ROUND SNACK BOX...  ( POSTAGE)
# 3     ( WOODLAND CHARLOTTE BAG,  JUMBO BAG WOODLAND ...  ( POSTAGE)
# 4     ( JUMBO BAG WOODLAND ANIMALS,  PLASTERS IN TIN...  ( POSTAGE)
# ...                                                 ...         ...
# 2523  ( ROUND SNACK BOXES SET OF4 WOODLAND ,  SPACEB...  ( POSTAGE)
# 2524                 ( VINTAGE DOILY TRAVEL SEWING KIT)  ( POSTAGE)
# 2525                    ( SPACEBOY ROCKET LOLLY MAKERS)  ( POSTAGE)
# 2526                  ( MINI LIGHTS WOODLAND MUSHROOMS)  ( POSTAGE)
# 2527                   ( TRADTIONAL ALPHABET STAMP SET)  ( POSTAGE)
#
#       confidence      lift
# 0       0.883721  1.522525
# 1       0.933333  1.608000
# 2       1.000000  1.722857
# 3       0.944444  1.627143
# 4       0.818182  1.409610
# ...          ...       ...
# 2523    1.000000  1.722857
# 2524    1.000000  1.722857
# 2525    1.000000  1.722857
# 2526    0.833333  1.435714
# 2527    0.888889  1.531429
#
# [2528 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = Germany_FP_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                             antecedents  \
# 1264  ( WHITE SPOT BLUE CERAMIC DRAWER KNOB,  BLUE S...
# 1591  ( POSTAGE,  RED SPOT CERAMIC DRAWER KNOB,  RED...
# 1584  ( WHITE SPOT BLUE CERAMIC DRAWER KNOB,  RED SP...
# 453   ( 6 RIBBONS RUSTIC CHARM,  BLUE HARMONICA IN B...
# 1574  ( WHITE SPOT BLUE CERAMIC DRAWER KNOB,  RED SP...
#
#                                 consequents  confidence       lift
# 1264                             ( POSTAGE)         1.0   1.722857
# 1591  ( WHITE SPOT RED CERAMIC DRAWER KNOB)         1.0  25.125000
# 1584                             ( POSTAGE)         1.0   1.722857
# 453                              ( POSTAGE)         1.0   1.722857
# 1574  ( WHITE SPOT RED CERAMIC DRAWER KNOB)         1.0  25.125000

# %% [markdown]
# # Germany_Apriori

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)

Germany_data = data[data['Country'] == 'Germany']

# 移除含有NaN值的行（特別是在'Description'列中）
Germany_data = Germany_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
Germany_data['Description'] = Germany_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
Germany_grouped_data = Germany_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
Germany_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536527  SET OF 6 T-LIGHTS SANTA, ROTATING SILVER ANGEL...
# 1    536840  JAM MAKING SET PRINTED, JAM JAR WITH PINK LID,...
# 2    536861  FELTCRAFT 6 FLOWER FRIENDS, 6 RIBBONS RUSTIC C...
# 3    536967                   POSTAGE, JUMBO BAG RED RETROSPOT
# 4    536983  WOODLAND PARTY BAG + STICKER SET, HAND WARMER ...

# %%
# Splitting the Description column into individual items
Germany_grouped_data['Items'] = Germany_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = Germany_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Generating the association rules
Germany_apriori_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
apriori_time = time.time() - start_time
print(f"Time taken for apriori: {apriori_time} seconds")
# Out:
# Time taken for apriori: 0.4527277946472168 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
Germany_apriori_rules = Germany_apriori_rules[['antecedents', 'consequents', 'confidence', 'lift']]
Germany_apriori_rules
# Out:
#                                             antecedents  \
# 0                             ( 10 COLOUR SPACEBOY PEN)
# 1                      ( 12 PENCIL SMALL TUBE WOODLAND)
# 2                      ( 12 PENCILS TALL TUBE WOODLAND)
# 3                         ( 3 HOOK HANGER MAGIC GARDEN)
# 4                 ( 3 PIECE SPACEBOY COOKIE CUTTER SET)
# ...                                                 ...
# 2523  ( RED SPOT CERAMIC DRAWER KNOB,  BLUE SPOT CER...
# 2524  ( BLUE SPOT CERAMIC DRAWER KNOB,  WHITE SPOT R...
# 2525  ( WHITE SPOT BLUE CERAMIC DRAWER KNOB,  RED ST...
# 2526  ( BLUE SPOT CERAMIC DRAWER KNOB,  RED STRIPE C...
# 2527  ( WHITE SPOT BLUE CERAMIC DRAWER KNOB,  BLUE S...
#
#                                             consequents  confidence       lift
# 0                                            ( POSTAGE)    1.000000   1.722857
# 1                                            ( POSTAGE)    0.777778   1.340000
# 2                                            ( POSTAGE)    0.800000   1.378286
# 3                                            ( POSTAGE)    0.705882   1.216134
# 4                                            ( POSTAGE)    0.750000   1.292143
# ...                                                 ...         ...        ...
# 2523  ( POSTAGE,  RED STRIPE CERAMIC DRAWER KNOB,  W...    0.777778  52.111111
# 2524  ( POSTAGE,  RED SPOT CERAMIC DRAWER KNOB,  RED...    0.700000  60.300000
# 2525  ( BLUE SPOT CERAMIC DRAWER KNOB,  POSTAGE,  RE...    0.700000  46.900000
# 2526  ( POSTAGE,  RED SPOT CERAMIC DRAWER KNOB,  WHI...    0.777778  58.625000
# 2527  ( POSTAGE,  RED STRIPE CERAMIC DRAWER KNOB,  R...    0.700000  42.210000
#
# [2528 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = Germany_apriori_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                             antecedents  \
# 0                             ( 10 COLOUR SPACEBOY PEN)
# 621   ( PINK VINTAGE SPOT BEAKER,  GREEN VINTAGE SPO...
# 1760  ( SCANDINAVIAN REDS RIBBONS,  CHOCOLATE BOX RI...
# 1758  ( SCANDINAVIAN REDS RIBBONS,  ROUND SNACK BOXE...
# 630               ( POSTAGE,  PINK VINTAGE SPOT BEAKER)
#
#                                  consequents  confidence       lift
# 0                                 ( POSTAGE)         1.0   1.722857
# 621              ( BLUE VINTAGE SPOT BEAKER)         1.0  43.071429
# 1760  ( ROUND SNACK BOXES SET OF4 WOODLAND )         1.0   5.432432
# 1758   ( ROUND SNACK BOXES SET OF 4 FRUITS )         1.0   8.148649
# 630              ( BLUE VINTAGE SPOT BEAKER)         1.0  43.071429

# %% [markdown]
# # France_FP

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
France_data = data[data['Country'] == 'France']

France_data = France_data.dropna(subset=['Description'])
France_data['Description'] = France_data['Description'].astype(str)

France_grouped_data = France_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
France_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536370  ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELIK...
# 1    536852  PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI J...
# 2    536974  EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PIN...
# 3    537065  HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER ST...
# 4    537463  JAM MAKING SET PRINTED, SET/4 SKULL BADGES, RO...

# %%
# Splitting the Description column into individual items
France_grouped_data['Items'] = France_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = France_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = fpgrowth(df, min_support=0.01, use_colnames=True)

# Generating the association rules
France_FP_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
fp_growth_time = time.time() - start_time
print(f"Time taken for FP-growth: {fp_growth_time} seconds")
# Out:
# Time taken for FP-growth: 0.5657899379730225 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
France_FP_rules = France_FP_rules[['antecedents', 'consequents', 'confidence', 'lift']]
France_FP_rules
# Out:
#                                              antecedents  \
# 0                       ( RED TOADSTOOL LED NIGHT LIGHT)
# 1      ( RED TOADSTOOL LED NIGHT LIGHT,  PLASTERS IN ...
# 2      ( POSTAGE,  RED TOADSTOOL LED NIGHT LIGHT,  PL...
# 3      ( PLASTERS IN TIN CIRCUS PARADE ,  RED TOADSTO...
# 4      ( PLASTERS IN TIN CIRCUS PARADE ,  RED TOADSTO...
# ...                                                  ...
# 38211                  ( MINI LIGHTS WOODLAND MUSHROOMS)
# 38212                  ( MINI LIGHTS WOODLAND MUSHROOMS)
# 38213  ( MINI LIGHTS WOODLAND MUSHROOMS,  RABBIT NIGH...
# 38214  ( RED TOADSTOOL LED NIGHT LIGHT,  MINI LIGHTS ...
# 38215                   ( TRADTIONAL ALPHABET STAMP SET)
#
#                              consequents  confidence      lift
# 0                             ( POSTAGE)    0.809524  1.357056
# 1                             ( POSTAGE)    0.947368  1.588134
# 2      ( PLASTERS IN TIN CIRCUS PARADE )    0.611111  4.204809
# 3                             ( POSTAGE)    1.000000  1.676364
# 4                             ( POSTAGE)    1.000000  1.676364
# ...                                  ...         ...       ...
# 38211              ( RABBIT NIGHT LIGHT)    0.625000  5.649510
# 38212                         ( POSTAGE)    0.750000  1.257273
# 38213                         ( POSTAGE)    0.700000  1.173455
# 38214              ( RABBIT NIGHT LIGHT)    0.833333  7.532680
# 38215                         ( POSTAGE)    0.857143  1.436883
#
# [38216 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = France_FP_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                              antecedents  \
# 28875  ( PLASTERS IN TIN SKULLS,  SPACEBOY LUNCH BOX ...
# 14962  ( ALARM CLOCK BAKELIKE ORANGE,  JUMBO BAG SPAC...
# 8176   ( LUNCH BOX I LOVE LONDON,  PLASTERS IN TIN CI...
# 29609  ( ALARM CLOCK BAKELIKE CHOCOLATE,  PLASTERS IN...
# 8178   ( LUNCH BOX I LOVE LONDON,  PLASTERS IN TIN SP...
#
#                                              consequents  confidence  \
# 28875  ( PLASTERS IN TIN WOODLAND ANIMALS,  CIRCUS PA...         1.0
# 14962                        ( PLASTERS IN TIN SPACEBOY)         1.0
# 8176                         ( PLASTERS IN TIN SPACEBOY)         1.0
# 29609                                         ( POSTAGE)         1.0
# 8178                   ( PLASTERS IN TIN CIRCUS PARADE )         1.0
#
#             lift
# 28875  51.222222
# 14962   8.537037
# 8176    8.537037
# 29609   1.676364
# 8178    6.880597

# %% [markdown]
# # France_Apriori

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import time

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)

France_data = data[data['Country'] == 'France']

France_data = France_data.dropna(subset=['Description'])
France_data['Description'] = France_data['Description'].astype(str)

France_grouped_data = France_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
France_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536370  ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELIK...
# 1    536852  PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI J...
# 2    536974  EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PIN...
# 3    537065  HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER ST...
# 4    537463  JAM MAKING SET PRINTED, SET/4 SKULL BADGES, RO...

# %%
# Splitting the Description column into individual items
France_grouped_data['Items'] = France_grouped_data['Description'].str.split(',')


# Start the timer for FP-growth algorithm
start_time = time.time()

# Extracting the list of transactions
transactions = France_grouped_data['Items'].tolist()

# TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# FP-growth 
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Generating the association rules
France_apriori_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)


# Stop the timer and print the time taken for FP-growth
apriori_time = time.time() - start_time
print(f"Time taken for apriori: {apriori_time} seconds")
# Out:
# Time taken for apriori: 1.9229347705841064 seconds

# %%
# Calculating confidence and lift
# These metrics are already included in the rules DataFrame
France_apriori_rules = France_apriori_rules[['antecedents', 'consequents', 'confidence', 'lift']]
France_apriori_rules
# Out:
#                                              antecedents  \
# 0                                       ( BIRTHDAY CARD)
# 1                                                    ( )
# 2                                            ( ELEPHANT)
# 3                                                    ( )
# 4                                                    ( )
# ...                                                  ...
# 38211  ( PACK OF 6 SKULL PAPER PLATES,  SET OF 9 HEAR...
# 38212  ( PACK OF 6 SKULL PAPER CUPS,  SET OF 9 HEART ...
# 38213  ( SET OF 9 HEART SHAPED BALLOONS,  SET/20 RED ...
# 38214  ( PACK OF 6 SKULL PAPER PLATES,  SET OF 9 HEAR...
# 38215  ( SET OF 9 HEART SHAPED BALLOONS,  SET/6 RED S...
#
#                                              consequents  confidence  \
# 0                                                    ( )    0.857143
# 1                                       ( BIRTHDAY CARD)    0.666667
# 2                                                    ( )    1.000000
# 3                                            ( ELEPHANT)    0.666667
# 4                                             ( POSTAGE)    0.777778
# ...                                                  ...         ...
# 38211  ( PACK OF 6 SKULL PAPER CUPS,  SET/6 RED SPOTT...    1.000000
# 38212  ( SET/6 RED SPOTTY PAPER PLATES,  SET/20 RED R...    0.625000
# 38213  ( PACK OF 6 SKULL PAPER CUPS,  SET/6 RED SPOTT...    0.625000
# 38214  ( PACK OF 6 SKULL PAPER CUPS,  SET/6 RED SPOTT...    0.625000
# 38215  ( PACK OF 6 SKULL PAPER CUPS,  SET/6 RED SPOTT...    0.714286
#
#             lift
# 0      43.904762
# 1      43.904762
# 2      51.222222
# 3      51.222222
# 4       1.303838
# ...          ...
# 38211  46.100000
# 38212  28.812500
# 38213  28.812500
# 38214  32.013889
# 38215  32.928571
#
# [38216 rows x 4 columns]

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = France_apriori_rules.sort_values(by='confidence', ascending=False)

# 選取前幾條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                              antecedents  \
# 18453  ( ALARM CLOCK BAKELIKE PINK,  PLASTERS IN TIN ...
# 14231  ( SET OF 9 BLACK SKULL BALLOONS,  PACK OF 6 SK...
# 7953   ( ALARM CLOCK BAKELIKE ORANGE,  SPACEBOY LUNCH...
# 30047  ( ALARM CLOCK BAKELIKE PINK,  PLASTERS IN TIN ...
# 14229  ( PACK OF 6 SKULL PAPER PLATES,  RETROSPOT PAR...
#
#                                              consequents  confidence  \
# 18453                      ( ALARM CLOCK BAKELIKE GREEN)         1.0
# 14231                    ( PACK OF 6 SKULL PAPER PLATES)         1.0
# 7953                        ( ALARM CLOCK BAKELIKE RED )         1.0
# 30047  ( PLASTERS IN TIN CIRCUS PARADE ,  ALARM CLOCK...         1.0
# 14229  ( PACK OF 20 SKULL PAPER NAPKINS,  PACK OF 6 S...         1.0
#
#             lift
# 18453  12.459459
# 14231  20.954545
# 7953   12.805556
# 30047  35.461538
# 14229  28.812500
