# %% [markdown]
# # Film

# %% [markdown]
# # 參考Kaggle上的

# %%
import pandas as pd

# Load the uploaded CSV file
file_path = 'TV Shows - Association Rule Learning.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#        Cobra Kai          Lupin   12 Monkeys          Sherlock  \
# 0           Lost      Jack Ryan    The Flash   Game of thrones
# 1  Sex Education      Dr. House      Kingdom  The Walking Dead
# 2          Ozark  Sex Education  Constantine          Preacher
# 3         Naruto            NaN          NaN               NaN
# 4  Sex Education            NaN          NaN               NaN
#
#        Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7     Unnamed: 8  \
# 0  House of Cards  12 Monkeys    Vikings     Fringe  The Mentalist
# 1             NaN         NaN        NaN        NaN            NaN
# 2         Vikings    The Tick        NaN        NaN            NaN
# 3             NaN         NaN        NaN        NaN            NaN
# 4             NaN         NaN        NaN        NaN            NaN
#
#      Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0  The Alienist  ...         NaN         NaN         NaN         NaN
# ...

# %%
# Add column headers as '欄位一', '欄位二', etc.
column_headers = [f'Column{i+1}' for i in range(data.shape[1])]
data.columns = column_headers

# Add an index column
# data.insert(0, 'index', range(1, len(data) + 1))

# Save the modified data to a new CSV file
# modified_file_path = 'Modified_TV_Shows_Association_Rule_Learning.csv'
# data.to_csv(modified_file_path, index=False)

data.head(5)
# Out:
#          Column1        Column2      Column3           Column4  \
# 0           Lost      Jack Ryan    The Flash   Game of thrones
# 1  Sex Education      Dr. House      Kingdom  The Walking Dead
# 2          Ozark  Sex Education  Constantine          Preacher
# 3         Naruto            NaN          NaN               NaN
# 4  Sex Education            NaN          NaN               NaN
#
#           Column5     Column6  Column7 Column8        Column9      Column10  \
# 0  House of Cards  12 Monkeys  Vikings  Fringe  The Mentalist  The Alienist
# 1             NaN         NaN      NaN     NaN            NaN           NaN
# 2         Vikings    The Tick      NaN     NaN            NaN           NaN
# 3             NaN         NaN      NaN     NaN            NaN           NaN
# 4             NaN         NaN      NaN     NaN            NaN           NaN
#
#    ... Column23 Column24 Column25 Column26 Column27 Column28 Column29  \
# ...

# %% [markdown]
# # Data processing

# %%
shows = data.values.astype(str).tolist()
shows
# Out:
# [['Lost',
#   'Jack Ryan',
#   'The Flash',
#   'Game of thrones',
#   'House of Cards',
#   '12 Monkeys',
#   'Vikings',
#   'Fringe',
#   'The Mentalist',
#   'The Alienist',
#   'Big Little Lies',
#   'Chernobyl',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['Sex Education',
#   'Dr. House',
#   'Kingdom',
#   'The Walking Dead',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['Ozark',
#   'Sex Education',
#   'Constantine',
#   'Preacher',
#   'Vikings',
#   'The Tick',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
from apyori import apriori

rules = apriori(transactions=shows,min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
result = list(rules)
result
# Out:
# [RelationRecord(items=frozenset({'Game of thrones', '12 Monkeys'}), support=0.0038187635462896066, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'12 Monkeys'}), confidence=0.22023809523809523, lift=3.763468967834047)]),
#  RelationRecord(items=frozenset({'Daredevil', 'Alice in Borderland'}), support=0.007121477964702239, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice in Borderland'}), items_add=frozenset({'Daredevil'}), confidence=0.2875, lift=3.0610851648351645)]),
#  RelationRecord(items=frozenset({'Arrow', 'The Wire'}), support=0.005779750232222107, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Arrow'}), items_add=frozenset({'The Wire'}), confidence=0.22134387351778653, lift=3.3667202362854534)]),
# ...

# %%
def inspect(result):
    lhs = [tuple(row[2][0][0])[0] for row in result]
    rhs = [tuple(row[2][0][1])[0] for row in result]
    support = [row[1] for row in result]
    confidence = [row[2][0][2] for row in result]
    lift = [row[2][0][-1] for row in result]
    return list(zip(lhs,rhs,support,confidence,lift))
resultdf = pd.DataFrame(inspect(result), columns=['LHS','RHS','Support','Confidence','Lift'])

# %%
resultdf.sort_values(by=['Lift'],axis=0,ascending=False)
# Out:
#                     LHS         RHS   Support  Confidence       Lift
# 8                Fringe        Lost  0.003096    0.379747  11.391229
# 9       Game of thrones     Vikings  0.004851    0.279762   8.289337
# 4               The 100        Dark  0.004644    0.416667   4.672550
# 10   Person of Interest   Mr. Robot  0.006915    0.429487   3.925756
# 7        Rick And Morty  Family Guy  0.009186    0.276398   3.864380
# 3          Breaking Bad    The Wire  0.004232    0.253086   3.849536
# 0       Game of thrones  12 Monkeys  0.003819    0.220238   3.763469
# 6              Punisher  Family Guy  0.004644    0.260116   3.636739
# 2                 Arrow    The Wire  0.005780    0.221344   3.366720
# 5       Game of thrones  Family Guy  0.004025    0.232143   3.245645
# 1   Alice in Borderland   Daredevil  0.007121    0.287500   3.061085
# 11   Queen of the South   Mr. Robot  0.017339    0.329412   3.011010

# %% [markdown]
# # 概念

# %% [markdown]
# # 自己寫的

# %% [markdown]
# 支持度（Support）：某商品在資料集出現的次數比例。例如：以上圖為例有 5 筆交易紀錄，有 3 筆交易有購買尿布，則 support （尿布）= 60%，而巧克力因只有出現一次的購買，則 support （巧克力）= 20%。除了單件商品的支持度，也可以計算兩件商品的支持度，如 support（尿布->啤酒）= 3/5 = 60%。

# %% [markdown]
# 信賴度（Confidence）：某一個種類 (A) 中，含有另一個種類 (B) 的比重，也就是在 A 出現的情況下，B 出現的機率值，以上圖為例，
# 我有 5 筆交易紀錄，其中 3 筆買過尿布，而這 3 筆買過尿布的當中，又另有 3 人買過啤酒，則confidence (尿布->啤酒) = 3/3 = 100% 。

# %% [markdown]
# 提升度（Lift）：某一個以規則組合出現及單獨出現的比值，公式為confidence(A->B) / support(B) ，提升度>1或越高表示兩個商品越相關、提升度=1表示為互相獨立、提升度<1或越低代表負相關性越高。帶入上述例子可表示成 lift (尿布->啤酒) = 100/80 = 1.25 。

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# 加載資料
data = pd.read_csv('TV Shows - Association Rule Learning.csv')

# 資料預處理
transactions = []
for i in range(data.shape[0]):
    transactions.append([str(data.values[i, j]) for j in range(data.shape[1]) if str(data.values[i, j]) != 'nan'])

# 使用 TransactionEncoder 轉換資料
te = TransactionEncoder()

te_ary = te.fit(transactions).transform(transactions)
# print(te_ary)
# print("-------")

df = pd.DataFrame(te_ary, columns=te.columns_)
# print(df)

# 使用 Apriori 算法找出最小支持度為 0.005 的所有頻繁項目集
frequent_itemsets_1 = apriori(df, min_support=0.005, use_colnames=True)

# 使用 Apriori 算法找出最小支持度為 0.003 的所有頻繁項目集
frequent_itemsets_2 = apriori(df, min_support=0.003, use_colnames=True)

# print(frequent_itemsets)

# %% [markdown]
# # 最小支持度為 0.005

# %% [raw]
# antecedent support: 先行項在資料集中出現的比例。
# consequent support: 後繼項在資料集中出現的比例。
# support: 先行項和後繼項組合在一起在資料集中出現的比例。
# confidence: 在先行項出現時，後繼項也出現的條件概率。
# lift: 觀察到的規則支持度與假設先行項和後繼項獨立時的支持度的比值。
# leverage: 表示先行項和後繼項一起出現與獨立出現的差異。它是 support 減去先行項和後繼項獨立時的支持度相乘的結果。
# conviction: 一個指標，顯示如果規則的先行項和後繼項是獨立的，先行項在沒有後繼項的情況下出現的頻率。它是 (1 - consequent support) / (1 - confidence)。
# zhangs_metric: 這是衡量規則興趣的指標，範圍從 -1 到 +1。正值表示正相關，負值表示負相關，0 表示無相關。

# %%
# 生成關聯規則 : 使用的度量是置信度（confidence），最小閾值設定為 0.6。這意味著只有那些置信度至少為 60% 的規則會被生成。
rules = association_rules(frequent_itemsets_1, metric="confidence", min_threshold=0.6)

# 顯示規則
rules
# Out:
#                                  antecedents      consequents  \
# 0                    (Dr. House, 12 Monkeys)  (Sex Education)
# 1                 (Atypical, Berlin Station)  (Sex Education)
# 2                (Dr. House, Berlin Station)  (Sex Education)
# 3               (Berlin Station, Family Guy)  (Sex Education)
# 4                (Mr. Robot, Berlin Station)  (Sex Education)
# 5          (Stranger Things, Berlin Station)  (Sex Education)
# 6            (The Blacklist, Berlin Station)  (Sex Education)
# 7                  (Demon Slayer, Dr. House)  (Sex Education)
# 8                 (Demon Slayer, Family Guy)          (Ozark)
# 9                 (Demon Slayer, Family Guy)  (Sex Education)
# 10                (Dr. House, The Blacklist)  (Sex Education)
# 11                (The Blacklist, Jack Ryan)  (Sex Education)
# 12                   (Mr. Robot, Succession)          (Ozark)
# 13           (Demon Slayer, Atypical, Ozark)  (Sex Education)
# ...

# %%
modified_file_path = 'Modified_1.csv'
rules.to_csv(modified_file_path, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset provided by the user
data_path = 'Modified_1.csv'
association_rules_df = pd.read_csv(data_path)

# Convert frozenset types of antecedents and consequents to string
association_rules_df['antecedents'] = association_rules_df['antecedents'].apply(lambda x: ', '.join(list(eval(x))))
association_rules_df['consequents'] = association_rules_df['consequents'].apply(lambda x: ', '.join(list(eval(x))))

# # Plot a scatter plot for support vs confidence
# plt.figure(figsize=(10, 8))
# plt.scatter(association_rules_df['support'], association_rules_df['confidence'], alpha=0.5)
# plt.title('Support vs Confidence')
# plt.xlabel('Support')
# plt.ylabel('Confidence')
# plt.grid(True)
# plt.show()

# Generate a heatmap for lift
pivot_table_lift = association_rules_df.pivot_table(index='antecedents', columns='consequents', values='lift')
plt.figure(figsize=(12, 10))
sns.heatmap(pivot_table_lift, annot=True, cmap='viridis')
plt.title('Heatmap of Lift for TV Shows Association Rules')
plt.xlabel('Consequents')
plt.ylabel('Antecedents')
plt.xticks(rotation=45, ha='right')  # Rotate X-axis labels for readability
plt.yticks(rotation=0)
plt.tight_layout()  # Adjust layout to display all elements properly
plt.show()

# %%
# 生成關聯規則 : 使用的度量是置信度（confidence），最小閾值設定為 0.6。這意味著只有那些置信度至少為 60% 的規則會被生成。
rules = association_rules(frequent_itemsets_2, metric="confidence", min_threshold=0.6)

# 顯示規則
rules
# Out:
#                                            antecedents      consequents  \
# 0                                       (Sacred Games)  (Sex Education)
# 1                              (Dr. House, 12 Monkeys)  (Sex Education)
# 2                               (12 Monkeys, The Wire)  (Sex Education)
# 3                     (Mr. Robot, Alice in Borderland)          (Ozark)
# 4                             (Archer, Berlin Station)  (Sex Education)
# ..                                                 ...              ...
# 111  (Mr. Robot, Atypical, The Blacklist, Sex Educa...          (Ozark)
# 112        (Ozark, Mr. Robot, Atypical, The Blacklist)  (Sex Education)
# 113  (Mr. Robot, The Blacklist, Cobra Kai, Sex Educ...          (Ozark)
# 114       (Ozark, Mr. Robot, The Blacklist, Cobra Kai)  (Sex Education)
# 115   (Ozark, Cobra Kai, The Blacklist, Sex Education)      (Mr. Robot)
#
#      antecedent support  consequent support   support  confidence      lift  \
# ...

# %% [markdown]
# # 最小支持度為 0.003

# %%
modified_file_path = 'Modified_2.csv'
rules.to_csv(modified_file_path, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset provided by the user
data_path = 'Modified_2.csv'
association_rules_df = pd.read_csv(data_path)

# Convert frozenset types of antecedents and consequents to string
association_rules_df['antecedents'] = association_rules_df['antecedents'].apply(lambda x: ', '.join(list(eval(x))))
association_rules_df['consequents'] = association_rules_df['consequents'].apply(lambda x: ', '.join(list(eval(x))))

# # Plot a scatter plot for support vs confidence
# plt.figure(figsize=(10, 8))
# plt.scatter(association_rules_df['support'], association_rules_df['confidence'], alpha=0.5)
# plt.title('Support vs Confidence')
# plt.xlabel('Support')
# plt.ylabel('Confidence')
# plt.grid(True)
# plt.show()

# Generate a heatmap for lift
pivot_table_lift = association_rules_df.pivot_table(index='antecedents', columns='consequents', values='lift')
plt.figure(figsize=(12, 10))
sns.heatmap(pivot_table_lift, annot=True, cmap='viridis')
plt.title('Heatmap of Lift for TV Shows Association Rules')
plt.xlabel('Consequents')
plt.ylabel('Antecedents')
plt.xticks(rotation=45, ha='right')  # Rotate X-axis labels for readability
plt.yticks(rotation=0)
plt.tight_layout()  # Adjust layout to display all elements properly
plt.show()

# %% [markdown]
# # OnlineRetail

# %%
import pandas as pd

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %% [markdown]
# # Data processing

# %% [markdown]
# 1. 同一張InvoiceNo的資料的Description轉成一筆資料

# %%
import pandas as pd


# 移除含有NaN值的行（特別是在'Description'列中）
data = data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
data['Description'] = data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
grouped_data = data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()

# 查看處理後的數據
print(grouped_data)


# Save the data to a new CSV file
grouped_data_path = 'grouped_data.csv'
grouped_data.to_csv(grouped_data_path, index=False)
# Out:
#       InvoiceNo                                        Description
# 0        536365  WHITE HANGING HEART T-LIGHT HOLDER, WHITE META...
# 1        536366  HAND WARMER UNION JACK, HAND WARMER RED POLKA DOT
# 2        536367  ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHOU...
# 3        536368  JAM MAKING SET WITH JARS, RED COAT RACK PARIS ...
# 4        536369                           BATH BUILDING BLOCK WORD
# ...         ...                                                ...
# 24441   C581484                        PAPER CRAFT , LITTLE BIRDIE
# 24442   C581490  VICTORIAN GLASS HANGING T-LIGHT, ZINC T-LIGHT ...
# 24443   C581499                                             Manual
# 24444   C581568                         VICTORIAN SEWING BOX LARGE
# 24445   C581569  HANGING HEART JAR T-LIGHT HOLDER, 36 PENCILS T...
#
# [24446 rows x 2 columns]

# %% [markdown]
# 2. apriori

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# 將描述列表轉換為交易列表
transactions = grouped_data['Description'].apply(lambda x: x.split(', ')).tolist()
#print(transactions)

# 初始化交易編碼器
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# 將交易數據轉換為適合進行Apriori算法的DataFrame格式
df = pd.DataFrame(te_ary, columns=te.columns_)

"""最小支持度為0.01"""

# 使用Apriori算法找出頻繁項集，設定最小支持度為0.01
frequent_itemsets_1 = apriori(df, min_support=0.01, use_colnames=True)

# 使用關聯規則函數生成規則，設定最小置信度為0.5
rules_1 = association_rules(frequent_itemsets_1, metric="confidence", min_threshold=0.6)

# 顯示生成的規則
rules_1.head()
# Out:
#                         antecedents                   consequents  \
# 0                   (BIRTHDAY CARD)                            ()
# 1        (FANCY FONT BIRTHDAY CARD)                            ()
# 2  (ALARM CLOCK BAKELIKE CHOCOLATE)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE CHOCOLATE)   (ALARM CLOCK BAKELIKE RED )
# 4      (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE RED )
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.017017            0.023603  0.011004    0.646635  27.396239
# 1            0.013254            0.023603  0.013254    1.000000  42.367418
# 2            0.018040            0.040947  0.011372    0.630385  15.395009
# 3            0.018040            0.044220  0.012108    0.671202  15.178723
# 4            0.040947            0.044220  0.026426    0.645355  14.594209
#
#    leverage  conviction  zhangs_metric
# 0  0.010602    2.763137       0.980178
# ...

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = rules_1.sort_values(by='confidence', ascending=False)

# 選取前10條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                            antecedents  \
# 39                                              (SHED)
# 8                                         (BACK DOOR )
# 1                           (FANCY FONT BIRTHDAY CARD)
# 11                                        (RETRO SPOT)
# 197  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...
#
#                     consequents  antecedent support  consequent support  \
# 39                   (KEY FOB )            0.015340            0.021721
# 8                    (KEY FOB )            0.012681            0.021721
# 1                            ()            0.013254            0.023603
# 11              (BIRTHDAY CARD)            0.011045            0.017017
# 197  (REGENCY TEA PLATE GREEN )            0.011127            0.015790
#
#       support  confidence       lift  leverage  conviction  zhangs_metric
# 39   0.015340    1.000000  46.037665  0.015007         inf       0.993519
# ...

# %%
# 對規則按提升度（lift）進行降序排序
sorted_rules_by_lift = rules_1.sort_values(by='lift', ascending=False)

# 選取前20條規則
top_rules_by_lift = sorted_rules_by_lift.head(5)
top_rules_by_lift
# Out:
#                                            antecedents  \
# 200                           (REGENCY TEA PLATE PINK)
# 196  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE G...
# 199                         (REGENCY TEA PLATE GREEN )
# 197  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...
# 12                                     (BIRTHDAY CARD)
#
#                                            consequents  antecedent support  \
# 200  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE G...            0.012845
# 196                           (REGENCY TEA PLATE PINK)            0.013172
# 199  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...            0.015790
# 197                         (REGENCY TEA PLATE GREEN )            0.011127
# 12                                        (RETRO SPOT)            0.017017
#
#      consequent support   support  confidence       lift  leverage  \
# 200            0.013172  0.010554    0.821656  62.379515  0.010385
# ...

# %%
"""最小支持度為0.02"""

# 使用Apriori算法找出頻繁項集，設定最小支持度為0.01
frequent_itemsets_2 = apriori(df, min_support=0.02, use_colnames=True)

# 使用關聯規則函數生成規則，設定最小置信度為0.5
rules_2 = association_rules(frequent_itemsets_2, metric="confidence", min_threshold=0.5)

# 顯示生成的規則
rules_2.head()
# Out:
#                      antecedents                    consequents  \
# 0    (ALARM CLOCK BAKELIKE RED )   (ALARM CLOCK BAKELIKE GREEN)
# 1   (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED )
# 2  (RED RETROSPOT CHARLOTTE BAG)  (CHARLOTTE BAG PINK POLKADOT)
# 3  (CHARLOTTE BAG PINK POLKADOT)  (RED RETROSPOT CHARLOTTE BAG)
# 4    (CHARLOTTE BAG SUKI DESIGN)  (RED RETROSPOT CHARLOTTE BAG)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.044220            0.040947  0.026426    0.597595  14.594209
# 1            0.040947            0.044220  0.026426    0.645355  14.594209
# 2            0.042952            0.031089  0.021517    0.500952  16.113529
# 3            0.031089            0.042952  0.021517    0.692105  16.113529
# 4            0.036570            0.042952  0.020862    0.570470  13.281624
#
#    leverage  conviction  zhangs_metric
# 0  0.024615    2.383301       0.974575
# 1  0.024615    2.695031       0.971250
# ...

# %% [markdown]
# # divide country

# %%
import pandas as pd

file_path = 'OnlineRetail_1225.csv'
data = pd.read_csv(file_path)
data.head(5)
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
unique_values = data['Country'].unique()
print(unique_values)
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Austria' 'Israel' 'Finland' 'Bahrain' 'Greece' 'Hong Kong'
#  'Singapore' 'Lebanon' 'United Arab Emirates' 'Saudi Arabia'
#  'Czech Republic' 'Canada' 'Unspecified' 'Brazil' 'USA'
#  'European Community' 'Malta' 'RSA']

# %%
value_counts = data['Country'].value_counts()
print(value_counts.head())
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Name: Country, dtype: int64

# %% [markdown]
# # UK

# %%
UK_data = data[data['Country'] == 'United Kingdom']
UK_data.head()
# Out:
#   InvoiceNo                          Description  Quantity       InvoiceDate  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01-12-2010 08:26
# 1    536365                  WHITE METAL LANTERN         6  01-12-2010 08:26
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8  01-12-2010 08:26
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01-12-2010 08:26
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6  01-12-2010 08:26
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
import pandas as pd


# 移除含有NaN值的行（特別是在'Description'列中）
UK_data = UK_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
UK_data['Description'] = UK_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
UK_grouped_data = UK_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
UK_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536365  WHITE HANGING HEART T-LIGHT HOLDER, WHITE META...
# 1    536366  HAND WARMER UNION JACK, HAND WARMER RED POLKA DOT
# 2    536367  ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHOU...
# 3    536368  JAM MAKING SET WITH JARS, RED COAT RACK PARIS ...
# 4    536369                           BATH BUILDING BLOCK WORD

# %%
# Save the data to a new CSV file
UK_grouped_data_path = 'UK_grouped_data.csv'
UK_grouped_data.to_csv(UK_grouped_data_path, index=False)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# 將描述列表轉換為交易列表
transactions = UK_grouped_data['Description'].apply(lambda x: x.split(', ')).tolist()
#print(transactions)

# 初始化交易編碼器
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# 將交易數據轉換為適合進行Apriori算法的DataFrame格式
df = pd.DataFrame(te_ary, columns=te.columns_)


# 使用Apriori算法找出頻繁項集，設定最小支持度為0.01
frequent_itemsets_1 = apriori(df, min_support=0.01, use_colnames=True)

# 使用關聯規則函數生成規則，設定最小置信度為0.5
rules_1 = association_rules(frequent_itemsets_1, metric="confidence", min_threshold=0.6)

# %%
rules_1.head()
# Out:
#                         antecedents                   consequents  \
# 0                   (BIRTHDAY CARD)                            ()
# 1        (FANCY FONT BIRTHDAY CARD)                            ()
# 2  (ALARM CLOCK BAKELIKE CHOCOLATE)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE CHOCOLATE)   (ALARM CLOCK BAKELIKE RED )
# 4      (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE RED )
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.017196            0.024365  0.011116    0.646438  26.531645
# 1            0.013884            0.024365  0.013884    1.000000  41.042831
# 2            0.017786            0.040563  0.011343    0.637755  15.722732
# 3            0.017786            0.043512  0.011661    0.655612  15.067460
# 4            0.040563            0.043512  0.025817    0.636465  14.627420
#
#    leverage  conviction  zhangs_metric
# 0  0.010697    2.759446       0.979147
# ...

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = rules_1.sort_values(by='confidence', ascending=False)

# 選取前10條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(5)
top_10_rules_by_confidence
# Out:
#                                            antecedents  \
# 42                                              (SHED)
# 1                           (FANCY FONT BIRTHDAY CARD)
# 8                                         (BACK DOOR )
# 11                                        (RETRO SPOT)
# 260  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...
#
#                     consequents  antecedent support  consequent support  \
# 42                   (KEY FOB )            0.016878            0.023911
# 1                            ()            0.013884            0.024365
# 8                    (KEY FOB )            0.013975            0.023911
# 11              (BIRTHDAY CARD)            0.011570            0.017196
# 260  (REGENCY TEA PLATE GREEN )            0.010753            0.015381
#
#       support  confidence       lift  leverage  conviction  zhangs_metric
# 42   0.016878    1.000000  41.821632  0.016475         inf       0.992847
# ...

# %%
# 對規則按提升度（lift）進行降序排序
sorted_rules_by_lift = rules_1.sort_values(by='lift', ascending=False)

# 選取前20條規則
top_rules_by_lift = sorted_rules_by_lift.head(5)
top_rules_by_lift
# Out:
#                                            antecedents  \
# 259  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE G...
# 263                           (REGENCY TEA PLATE PINK)
# 260  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...
# 262                         (REGENCY TEA PLATE GREEN )
# 11                                        (RETRO SPOT)
#
#                                            consequents  antecedent support  \
# 259                           (REGENCY TEA PLATE PINK)            0.012795
# 263  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE G...            0.012341
# 260                         (REGENCY TEA PLATE GREEN )            0.010753
# 262  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...            0.015381
# 11                                     (BIRTHDAY CARD)            0.011570
#
#      consequent support   support  confidence       lift  leverage  \
# 259            0.012341  0.010163    0.794326  64.363788  0.010005
# ...

# %% [markdown]
# # Germany

# %%
Germany_data = data[data['Country'] == 'Germany']
Germany_data.head()
# Out:
#      InvoiceNo                          Description  Quantity  \
# 1109    536527              SET OF 6 T-LIGHTS SANTA         6
# 1110    536527  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111    536527   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112    536527        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113    536527           3 HOOK HANGER MAGIC GARDEN        12
#
#            InvoiceDate  UnitPrice  CustomerID  Country
# 1109  01-12-2010 13:04       2.95     12662.0  Germany
# 1110  01-12-2010 13:04       2.55     12662.0  Germany
# 1111  01-12-2010 13:04       0.85     12662.0  Germany
# 1112  01-12-2010 13:04       1.65     12662.0  Germany
# 1113  01-12-2010 13:04       1.95     12662.0  Germany

# %%
import pandas as pd


# 移除含有NaN值的行（特別是在'Description'列中）
Germany_data = Germany_data.dropna(subset=['Description'])

# 將所有描述轉換為字符串類型
Germany_data['Description'] = Germany_data['Description'].astype(str)

# 按InvoiceNo分組，並將每組的描述字段合併為一個字串
Germany_grouped_data = Germany_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()
Germany_grouped_data.head()
# Out:
#   InvoiceNo                                        Description
# 0    536527  SET OF 6 T-LIGHTS SANTA, ROTATING SILVER ANGEL...
# 1    536840  JAM MAKING SET PRINTED, JAM JAR WITH PINK LID,...
# 2    536861  FELTCRAFT 6 FLOWER FRIENDS, 6 RIBBONS RUSTIC C...
# 3    536967                   POSTAGE, JUMBO BAG RED RETROSPOT
# 4    536983  WOODLAND PARTY BAG + STICKER SET, HAND WARMER ...

# %%
# Save the data to a new CSV file
Germany_grouped_data_path = 'Germany_grouped_data.csv'
Germany_grouped_data.to_csv(Germany_grouped_data_path, index=False)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# 將描述列表轉換為交易列表
transactions = Germany_grouped_data['Description'].apply(lambda x: x.split(', ')).tolist()
#print(transactions)

# 初始化交易編碼器
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# 將交易數據轉換為適合進行Apriori算法的DataFrame格式
df = pd.DataFrame(te_ary, columns=te.columns_)


# 使用Apriori算法找出頻繁項集，設定最小支持度為0.01
frequent_itemsets_1 = apriori(df, min_support=0.01, use_colnames=True)

# 使用關聯規則函數生成規則，設定最小置信度為0.5
rules_1 = association_rules(frequent_itemsets_1, metric="confidence", min_threshold=0.6)

# 顯示生成的規則
# rules_1.head()

# %%
# 對規則按confidence進行降序排序
sorted_rules_by_confidence = rules_1.sort_values(by='confidence', ascending=False)

# 選取前10條規則
top_10_rules_by_confidence = sorted_rules_by_confidence.head(10)
top_10_rules_by_confidence
# Out:
#                                             antecedents  \
# 531    (RED  HARMONICA IN BOX , BLUE HARMONICA IN BOX )
# 2148  (RETROSPOT PARTY BAG + STICKER SET, DINOSAUR P...
# 2162  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS ...
# 2161  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS ...
# 636   (WHITE SPOT RED CERAMIC DRAWER KNOB, BLUE SPOT...
# 1130  (RED RETROSPOT CHARLOTTE BAG, LUNCH BAG WOODLAND)
# 1537  (WATERING CAN PINK BUNNY, WATERING CAN BLUE EL...
# 2155  (DOLLY GIRL CHILDRENS BOWL, POSTAGE, SPACEBOY ...
# 1544   (WOODLAND CHARLOTTE BAG, WOODLAND MINI BACKPACK)
# 644   (WHITE SPOT BLUE CERAMIC DRAWER KNOB, RED SPOT...
#
#                                       consequents  antecedent support  \
# 531                                     (POSTAGE)            0.021559
# 2148  (WOODLAND PARTY BAG + STICKER SET, POSTAGE)            0.013267
# 2162                   (DOLLY GIRL CHILDRENS CUP)            0.011609
# ...

# %%
# 對規則按提升度（lift）進行降序排序
sorted_rules_by_lift = rules_1.sort_values(by='lift', ascending=False)

# 選取前20條規則
top_rules_by_lift = sorted_rules_by_lift.head(10)
top_rules_by_lift
# Out:
#                                             antecedents  \
# 1968  (GREEN VINTAGE SPOT BEAKER, BLUE VINTAGE SPOT ...
# 1973  (PINK VINTAGE SPOT BEAKER, RED VINTAGE SPOT BE...
# 2108  (CHOCOLATE BOX RIBBONS , ROUND SNACK BOXES SET...
# 2107  (SCANDINAVIAN REDS RIBBONS, ROUND SNACK BOXES ...
# 2105  (ROUND SNACK BOXES SET OF 4 FRUITS , CHOCOLATE...
# 172                  (STAR WREATH DECORATION WITH BELL)
# 173                 (HEART WREATH DECORATION WITH BELL)
# 2104  (ROUND SNACK BOXES SET OF 4 FRUITS , SCANDINAV...
# 2172  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS ...
# 2175  (DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS...
#
#                                             consequents  antecedent support  \
# 1968  (PINK VINTAGE SPOT BEAKER, RED VINTAGE SPOT BE...            0.011609
# 1973  (GREEN VINTAGE SPOT BEAKER, BLUE VINTAGE SPOT ...            0.013267
# 2108  (ROUND SNACK BOXES SET OF 4 FRUITS , SCANDINAV...            0.014925
# ...

# %% [markdown]
# # France

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

France_data = data[data['Country'] == 'France']

France_data = France_data.dropna(subset=['Description'])
France_data['Description'] = France_data['Description'].astype(str)

France_grouped_data = France_data.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x)).reset_index()

# Apriori
transactions = France_grouped_data['Description'].apply(lambda x: x.split(', ')).tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# confidence
sorted_rules_by_confidence = rules.sort_values(by='confidence', ascending=False)
top_rules_by_confidence = sorted_rules_by_confidence.head(10)

# lift
sorted_rules_by_lift = rules.sort_values(by='lift', ascending=False)
top_rules_by_lift = sorted_rules_by_lift.head(10)

# %%
top_rules_by_confidence
# Out:
#                                              antecedents  \
# 26564  (SPACEBOY LUNCH BOX , LUNCH BAG SPACEBOY DESIG...
# 22591  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES, ALARM...
# 22641  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...
# 22640  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...
# 47878  (ALARM CLOCK BAKELIKE GREEN, PLASTERS IN TIN S...
# 22631  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 22627  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...
# 22626  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 22615  (ALARM CLOCK BAKELIKE GREEN, STRAWBERRY LUNCH ...
# 22601  (SPACEBOY LUNCH BOX , ALARM CLOCK BAKELIKE GRE...
#
#                                              consequents  antecedent support  \
# 26564                         (PLASTERS IN TIN SPACEBOY)            0.010846
# 22591  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.010846
# 22641              (ROUND SNACK BOXES SET OF4 WOODLAND )            0.010846
# ...

# %%
top_rules_by_lift
# Out:
#                                              antecedents  \
# 41057  (CHILDRENS CUTLERY DOLLY GIRL , ALARM CLOCK BA...
# 47784  (SET/6 RED SPOTTY PAPER CUPS, ALARM CLOCK BAKE...
# 47890  (PLASTERS IN TIN SPACEBOY, ALARM CLOCK BAKELIK...
# 47888  (ALARM CLOCK BAKELIKE GREEN, PLASTERS IN TIN S...
# 41058  (CHILDRENS CUTLERY DOLLY GIRL , ALARM CLOCK BA...
# 47864  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...
# 47818  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...
# 47815  (SET/6 RED SPOTTY PAPER PLATES, ROUND SNACK BO...
# 47813  (SET/6 RED SPOTTY PAPER CUPS, PLASTERS IN TIN ...
# 47791  (SET/6 RED SPOTTY PAPER PLATES, ROUND SNACK BO...
#
#                                              consequents  antecedent support  \
# 41057  (ROUND SNACK BOXES SET OF4 WOODLAND , ALARM CL...            0.010846
# 47784  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...            0.010846
# 47890  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES...            0.010846
# ...
